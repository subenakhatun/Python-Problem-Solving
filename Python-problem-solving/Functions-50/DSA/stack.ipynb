# %%
book_list=[]
ask_book = input(" ")
book_list.append(ask_book)
print(book_list)
# Out:
# ['subena']

# %%
item_number = 10
iteam_empty = []
for i in range(1,11):
    ask_book = input(" ")
    iteam_empty.append(ask_book)
print(f"item-empty:{iteam_empty}")
# Out:
# item-empty:['ss', 'sss', 'ssss', 'ssss', 'ssss', 'ssss', 'sssss', 'sssss', 'ssssss', 'ssss']
